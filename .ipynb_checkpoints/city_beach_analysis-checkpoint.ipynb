# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
beach_quality_df = pd.read_csv('Resources/Beach_Water_Quality.csv')
beach_quality_df.head()
# Out:
#           Beach Name Measurement Timestamp  Water Temperature  Turbidity  \
# 0  Ohio Street Beach          6/2/19 17:00               17.1       0.78
# 1  63rd Street Beach         9/18/13 10:00               18.9       7.56
# 2  63rd Street Beach         6/12/14 12:00               25.4       3.45
# 3  63rd Street Beach         6/12/14 13:00               18.1       3.31
# 4  63rd Street Beach         6/12/14 14:00               17.5       2.93
#
#    Transducer Depth  Wave Height  Wave Period  Battery Life  \
# 0               NaN        0.232          4.0          10.9
# 1             1.517        0.140          4.0          11.0
# 2            -0.072        0.031          9.0          12.2
# 3             1.818        0.339         10.0          12.2
# 4             1.545        0.136          4.0          12.2
#
#   Measurement Timestamp Label               Measurement ID
# 0                6/2/19 17:00  OhioStreetBeach201906021700
# 1               9/18/13 10:00  63rdStreetBeach201309181000
# 2               6/12/14 12:00  63rdStreetBeach201406121200
# 3               6/12/14 13:00  63rdStreetBeach201406121300
# 4               6/12/14 14:00  63rdStreetBeach201406121400

# %%
beach_quality_df['Turbidity'].head()
# Out:
# 0    0.78
# 1    7.56
# 2    3.45
# 3    3.31
# 4    2.93
# Name: Turbidity, dtype: float64

# %%
beach_quality_df['Beach Name'].count()
# Out:
# 39469

# %%
turbidity_means = beach_quality_df.groupby("Beach Name")["Turbidity"].mean()
turbidity_means
# Out:
# Beach Name
# 63rd Street Beach    4.313150
# Calumet Beach        1.886594
# Montrose Beach       2.898791
# Ohio Street Beach    5.951276
# Osterman Beach       8.707598
# Rainbow Beach        3.164116
# Name: Turbidity, dtype: float64

# %%
beach_quality_df.shape
# Out:
# (39469, 10)

# %%
x = turbidity_means.plot.bar()

# %%
selected_beach_quality_df = beach_quality_df[['Beach Name','Measurement Timestamp','Water Temperature','Turbidity','Wave Height', 'Wave Period']].copy()
selected_beach_quality_df.head()
# Out:
#           Beach Name Measurement Timestamp  Water Temperature  Turbidity  \
# 0  Ohio Street Beach          6/2/19 17:00               17.1       0.78
# 1  63rd Street Beach         9/18/13 10:00               18.9       7.56
# 2  63rd Street Beach         6/12/14 12:00               25.4       3.45
# 3  63rd Street Beach         6/12/14 13:00               18.1       3.31
# 4  63rd Street Beach         6/12/14 14:00               17.5       2.93
#
#    Wave Height  Wave Period
# 0        0.232          4.0
# 1        0.140          4.0
# 2        0.031          9.0
# 3        0.339         10.0
# 4        0.136          4.0

# %%
temperature = beach_quality_df.groupby("Beach Name")["Water Temperature"].mean()
temperature
# Out:
# Beach Name
# 63rd Street Beach    18.459901
# Calumet Beach        20.373104
# Montrose Beach       18.640534
# Ohio Street Beach    20.339365
# Osterman Beach       17.933615
# Rainbow Beach        18.741250
# Name: Water Temperature, dtype: float64

# %%
xtemps = temperature.plot.bar()

# %%
beach_quality_df.isnull().sum()
# Out:
# Beach Name                         0
# Measurement Timestamp              0
# Water Temperature                  0
# Turbidity                          0
# Transducer Depth               29435
# Wave Height                      229
# Wave Period                      227
# Battery Life                       0
# Measurement Timestamp Label        0
# Measurement ID                     0
# dtype: int64

# %%
beach_quality_df[beach_quality_df.Turbidity.isnull()]
# Out:
# Empty DataFrame
# Columns: [Beach Name, Measurement Timestamp, Water Temperature, Turbidity, Transducer Depth, Wave Height, Wave Period, Battery Life, Measurement Timestamp Label, Measurement ID]
# Index: []

# %%
temperature = beach_quality_df.groupby("Beach Name")["Water Temperature"].mean()
temperature
# Out:
# Beach Name
# 63rd Street Beach    18.459901
# Calumet Beach        20.373104
# Montrose Beach       18.640534
# Ohio Street Beach    20.339365
# Osterman Beach       17.933615
# Rainbow Beach        18.741250
# Name: Water Temperature, dtype: float64

# %%
waves = beach_quality_df.groupby("Beach Name")["Wave Height"].mean()
waves
# Out:
# Beach Name
# 63rd Street Beach    -1347.386252
# Calumet Beach            0.152585
# Montrose Beach           0.202249
# Ohio Street Beach     -287.751254
# Osterman Beach           0.184694
# Rainbow Beach       -13379.676708
# Name: Wave Height, dtype: float64

# %%
xwaves = waves.plot.bar()

# %%
beach_quality_df.dropna(subset= ['Wave Height']).shape
# Out:
# (39240, 10)

# %%
waves.replace('', np.NaN)
# Out:
# Beach Name
# 63rd Street Beach    -1347.386252
# Calumet Beach            0.152585
# Montrose Beach           0.202249
# Ohio Street Beach     -287.751254
# Osterman Beach           0.184694
# Rainbow Beach       -13379.676708
# Name: Wave Height, dtype: float64

# %%
beach_quality_df.columns = [c.replace(' ', '_') for c in beach_quality_df.columns]

# %%
beach_quality_df.columns
# Out:
# Index(['Beach_Name', 'Measurement_Timestamp', 'Water_Temperature', 'Turbidity',
#        'Transducer_Depth', 'Wave_Height', 'Wave_Period', 'Battery_Life',
#        'Measurement_Timestamp_Label', 'Measurement_ID'],
#       dtype='object')

# %%
beach_quality_df[beach_quality_df.Wave_Height<0]
# Out:
#               Beach_Name Measurement_Timestamp  Water_Temperature  Turbidity  \
# 3375   63rd Street Beach         9/11/15 19:00               20.0       5.83
# 3376   63rd Street Beach         9/11/15 21:00               19.5       8.81
# 3377   63rd Street Beach         9/11/15 22:00               19.2      14.59
# 3378   63rd Street Beach         9/11/15 23:00               19.1       9.56
# 3380   63rd Street Beach          9/12/15 1:00               19.2      14.10
# ...                  ...                   ...                ...        ...
# 34914      Rainbow Beach          10/1/15 2:00               16.2      55.64
# 34915      Rainbow Beach          10/1/15 3:00               16.2      21.96
# 34916      Rainbow Beach          10/1/15 4:00               15.8       0.15
# 34917      Rainbow Beach          10/1/15 5:00               15.9       8.59
# 34918      Rainbow Beach          10/1/15 6:00               15.8     357.35
#
#        Transducer_Depth  Wave_Height  Wave_Period  Battery_Life  \
# 3375                NaN   -99999.992    -100000.0          10.6
# 3376                NaN   -99999.992    -100000.0           5.6
# 3377                NaN   -99999.992    -100000.0           5.3
# 3378                NaN   -99999.992    -100000.0           5.5
# 3380                NaN   -99999.992    -100000.0           5.4
# ...                 ...          ...          ...           ...
# 34914               NaN   -99999.992    -100000.0           9.5
# 34915               NaN   -99999.992    -100000.0           5.3
# 34916               NaN   -99999.992    -100000.0          10.4
# 34917               NaN   -99999.992    -100000.0           5.7
# 34918               NaN   -99999.992    -100000.0          10.4
#
#       Measurement_Timestamp_Label               Measurement_ID
# 3375                9/11/15 19:00  63rdStreetBeach201509111900
# 3376                9/11/15 21:00  63rdStreetBeach201509112100
# 3377                9/11/15 22:00  63rdStreetBeach201509112200
# 3378                9/11/15 23:00  63rdStreetBeach201509112300
# 3380                 9/12/15 1:00  63rdStreetBeach201509120100
# ...                           ...                          ...
# 34914                10/1/15 2:00     RainbowBeach201510010200
# 34915                10/1/15 3:00     RainbowBeach201510010300
# 34916                10/1/15 4:00     RainbowBeach201510010400
# 34917                10/1/15 5:00     RainbowBeach201510010500
# 34918                10/1/15 6:00     RainbowBeach201510010600
#
# [524 rows x 10 columns]

# %%
negatives = beach_quality_df[beach_quality_df['Wave_Height'] < 0]
negatives
# Out:
#               Beach_Name Measurement_Timestamp  Water_Temperature  Turbidity  \
# 3375   63rd Street Beach         9/11/15 19:00               20.0       5.83
# 3376   63rd Street Beach         9/11/15 21:00               19.5       8.81
# 3377   63rd Street Beach         9/11/15 22:00               19.2      14.59
# 3378   63rd Street Beach         9/11/15 23:00               19.1       9.56
# 3380   63rd Street Beach          9/12/15 1:00               19.2      14.10
# ...                  ...                   ...                ...        ...
# 34914      Rainbow Beach          10/1/15 2:00               16.2      55.64
# 34915      Rainbow Beach          10/1/15 3:00               16.2      21.96
# 34916      Rainbow Beach          10/1/15 4:00               15.8       0.15
# 34917      Rainbow Beach          10/1/15 5:00               15.9       8.59
# 34918      Rainbow Beach          10/1/15 6:00               15.8     357.35
#
#        Transducer_Depth  Wave_Height  Wave_Period  Battery_Life  \
# 3375                NaN   -99999.992    -100000.0          10.6
# 3376                NaN   -99999.992    -100000.0           5.6
# 3377                NaN   -99999.992    -100000.0           5.3
# 3378                NaN   -99999.992    -100000.0           5.5
# 3380                NaN   -99999.992    -100000.0           5.4
# ...                 ...          ...          ...           ...
# 34914               NaN   -99999.992    -100000.0           9.5
# 34915               NaN   -99999.992    -100000.0           5.3
# 34916               NaN   -99999.992    -100000.0          10.4
# 34917               NaN   -99999.992    -100000.0           5.7
# 34918               NaN   -99999.992    -100000.0          10.4
#
#       Measurement_Timestamp_Label               Measurement_ID
# 3375                9/11/15 19:00  63rdStreetBeach201509111900
# 3376                9/11/15 21:00  63rdStreetBeach201509112100
# 3377                9/11/15 22:00  63rdStreetBeach201509112200
# 3378                9/11/15 23:00  63rdStreetBeach201509112300
# 3380                 9/12/15 1:00  63rdStreetBeach201509120100
# ...                           ...                          ...
# 34914                10/1/15 2:00     RainbowBeach201510010200
# 34915                10/1/15 3:00     RainbowBeach201510010300
# 34916                10/1/15 4:00     RainbowBeach201510010400
# 34917                10/1/15 5:00     RainbowBeach201510010500
# 34918                10/1/15 6:00     RainbowBeach201510010600
#
# [524 rows x 10 columns]

# %%
newdf=beach_quality_df[beach_quality_df.Wave_Height > 0]
newdf
# Out:
#               Beach_Name Measurement_Timestamp  Water_Temperature  Turbidity  \
# 0      Ohio Street Beach          6/2/19 17:00               17.1       0.78
# 1      63rd Street Beach         9/18/13 10:00               18.9       7.56
# 2      63rd Street Beach         6/12/14 12:00               25.4       3.45
# 3      63rd Street Beach         6/12/14 13:00               18.1       3.31
# 4      63rd Street Beach         6/12/14 14:00               17.5       2.93
# ...                  ...                   ...                ...        ...
# 39462  Ohio Street Beach          9/7/19 15:00               19.2      20.78
# 39464      Calumet Beach         9/20/16 13:00               21.7       3.15
# 39465     Montrose Beach         9/14/16 19:00               21.9       0.01
# 39466  Ohio Street Beach         9/11/19 11:00               23.8       0.00
# 39467     Osterman Beach         9/10/15 10:00               18.6       0.37
#
#        Transducer_Depth  Wave_Height  Wave_Period  Battery_Life  \
# 0                   NaN        0.232          4.0          10.9
# 1                 1.517        0.140          4.0          11.0
# 2                -0.072        0.031          9.0          12.2
# 3                 1.818        0.339         10.0          12.2
# 4                 1.545        0.136          4.0          12.2
# ...                 ...          ...          ...           ...
# 39462               NaN        0.192          4.0          10.5
# 39464               NaN        0.389          3.0           9.4
# 39465               NaN        0.360          3.0           9.4
# 39466               NaN        0.028         10.0          10.2
# 39467               NaN        0.159          2.0          11.6
#
#       Measurement_Timestamp_Label               Measurement_ID
# 0                    6/2/19 17:00  OhioStreetBeach201906021700
# 1                   9/18/13 10:00  63rdStreetBeach201309181000
# 2                   6/12/14 12:00  63rdStreetBeach201406121200
# 3                   6/12/14 13:00  63rdStreetBeach201406121300
# 4                   6/12/14 14:00  63rdStreetBeach201406121400
# ...                           ...                          ...
# 39462                9/7/19 15:00  OhioStreetBeach201909071500
# 39464               9/20/16 13:00     CalumetBeach201609201300
# 39465               9/14/16 19:00    MontroseBeach201609141900
# 39466               9/11/19 11:00  OhioStreetBeach201909111100
# 39467               9/10/15 10:00    OstermanBeach201509101000
#
# [38716 rows x 10 columns]

# %%
Wave_Height = newdf.groupby("Beach_Name")["Wave_Height"].mean()
Wave_Height
# Out:
# Beach_Name
# 63rd Street Beach    0.155694
# Calumet Beach        0.152585
# Montrose Beach       0.202249
# Ohio Street Beach    0.163972
# Osterman Beach       0.184694
# Rainbow Beach        0.203868
# Name: Wave_Height, dtype: float64

# %%
xwaves = Wave_Height.plot.bar()

# %%
beach_advisory_df = pd.read_csv('Resources/Beach_Swim_Advisories.csv')
beach_advisory_df.head()
# Out:
#    Beach Name    Date  Predicted Level  Probability Swim Advisory  \
# 0  63rdStreet  6/4/16             33.6        0.106             N
# 1     Calumet  6/4/16             33.8        0.107             N
# 2      Foster  6/4/16             14.9        0.021             N
# 3       Leone  6/4/16              9.6        0.006             N
# 4    Montrose  6/4/16            101.5        0.277             N
#
#              RecordID
# 0  63rdStreet20160604
# 1     Calumet20160604
# 2      Foster20160604
# 3       Leone20160604
# 4    Montrose20160604

# %%
beach_advisory_df.shape
# Out:
# (972, 6)

# %%
selected_beach_advisory_df = beach_advisory_df[['Beach Name','Predicted Level', 'Swim Advisory']].copy()
selected_beach_advisory_df.head()
# Out:
#    Beach Name  Predicted Level Swim Advisory
# 0  63rdStreet             33.6             N
# 1     Calumet             33.8             N
# 2      Foster             14.9             N
# 3       Leone              9.6             N
# 4    Montrose            101.5             N

# %%
selected_beach_advisory_df.groupby(['Beach Name','Swim Advisory']).count()
df1 = selected_beach_advisory_df.groupby(['Beach Name','Swim Advisory']).count()

# %%
beach_weather_df = pd.read_csv('Resources/Beach_Weather_Stations.csv')
beach_weather_df.head()
# Out:
#                   Station Name Measurement Timestamp  Air Temperature  \
# 0  63rd Street Weather Station           1/1/16 0:00            -2.80
# 1       Foster Weather Station           1/1/16 0:00            -3.67
# 2   Oak Street Weather Station           1/1/16 0:00            -2.30
# 3  63rd Street Weather Station           1/1/16 1:00            -3.40
# 4       Foster Weather Station           1/1/16 1:00            -4.56
#
#    Wet Bulb Temperature  Humidity  Rain Intensity  Interval Rain  Total Rain  \
# 0                  -4.4        69             0.0            0.0         6.7
# 1                   NaN        62             NaN            0.0         NaN
# 2                  -4.0        67             0.0            0.0         6.3
# 3                  -4.8        72             0.0            0.0         6.7
# 4                   NaN        63             NaN            0.0         NaN
#
#    Precipitation Type  Wind Direction  Wind Speed  Maximum Wind Speed  \
# 0                 0.0             255         3.8                 6.4
# 1                 NaN             197         3.6                 5.0
# 2                 0.0             260         4.0                 7.6
# 3                 0.0             273         6.4                 9.4
# 4                 NaN             290         5.9                 6.6
#
#    Barometric Pressure  Solar Radiation  Heading  Battery Life  \
# 0               1000.5                5    353.0          11.9
# 1               1000.0                0      NaN          15.2
# 2               1000.5                3    359.0          12.1
# 3                999.9                5    353.0          11.9
# 4                999.3                0      NaN          14.8
#
#   Measurement Timestamp Label                        Measurement ID
# 0                 1/1/16 0:00  63rdStreetWeatherStation201601012400
# 1                 1/1/16 0:00      FosterWeatherStation201601012400
# 2                 1/1/16 0:00   OakStreetWeatherStation201601012400
# 3                 1/1/16 1:00  63rdStreetWeatherStation201601010100
# 4                 1/1/16 1:00      FosterWeatherStation201601010100

# %%
beach_weather_df.shape
# Out:
# (23686, 18)

# %%
selected_beach_weather_df = beach_weather_df[['Station Name','Rain Intensity', 'Wind Speed']].copy()
selected_beach_weather_df.head()
# Out:
#                   Station Name  Rain Intensity  Wind Speed
# 0  63rd Street Weather Station             0.0         3.8
# 1       Foster Weather Station             NaN         3.6
# 2   Oak Street Weather Station             0.0         4.0
# 3  63rd Street Weather Station             0.0         6.4
# 4       Foster Weather Station             NaN         5.9

# %%
beach_E_coli_df = pd.read_csv('Resources/Beach_E_Coli_Predictions.csv')
beach_E_coli_df.head()
# Out:
#     Beach Name        Date Prediction Source  Predicted Level  \
# 0  12th Street  05/26/2017         DNA Model            160.0
# 1  12th Street  05/27/2017         DNA Model             54.7
# 2  12th Street  05/28/2017         DNA Model             85.9
# 3  12th Street  05/29/2017         DNA Model            109.5
# 4  12th Street  05/30/2017         DNA Model             53.2
#
#              RecordID  Latitude  Longitude             Location
# 0  12thStreet20170526   41.8638   -87.6082  (41.8638, -87.6082)
# 1  12thStreet20170527   41.8638   -87.6082  (41.8638, -87.6082)
# 2  12thStreet20170528   41.8638   -87.6082  (41.8638, -87.6082)
# 3  12thStreet20170529   41.8638   -87.6082  (41.8638, -87.6082)
# 4  12thStreet20170530   41.8638   -87.6082  (41.8638, -87.6082)

# %%
selected_beach_E_coli_df = beach_E_coli_df[['Beach Name','Date', 'Predicted Level','Latitude','Longitude','Location']].copy()
selected_beach_E_coli_df.head()
# Out:
#     Beach Name        Date  Predicted Level  Latitude  Longitude  \
# 0  12th Street  05/26/2017            160.0   41.8638   -87.6082
# 1  12th Street  05/27/2017             54.7   41.8638   -87.6082
# 2  12th Street  05/28/2017             85.9   41.8638   -87.6082
# 3  12th Street  05/29/2017            109.5   41.8638   -87.6082
# 4  12th Street  05/30/2017             53.2   41.8638   -87.6082
#
#               Location
# 0  (41.8638, -87.6082)
# 1  (41.8638, -87.6082)
# 2  (41.8638, -87.6082)
# 3  (41.8638, -87.6082)
# 4  (41.8638, -87.6082)
